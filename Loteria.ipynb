# %%
#simulando uma jogada aleatória

import numpy as np

a = np.random.randint(1,61,6)
b = np.random.randint(1,61,6)

def remover_repetidos(lista):
    l = []
    for i in lista:
        while i in l:
            i = np.random.randint(1,61)
        l.append(i)
        if i not in l:
            l.append(i)
    l.sort()
    return l

a = remover_repetidos(a)
b = remover_repetidos(b)
print('Os números sorteados foram:', a)
print('Os números jogados foram:', b)

n=0
r=[]

for i in a:
    if i in b:
        n+=1
        r.append(i)
     
print('Números acertados:', r)
print('Quantidade de números acertados:', n)

# %%
#simulando o n° de tentativas para pelo menos 4 números acertados (prêmio mínimo)

import numpy as np

c=0
n=0
r=[]

while n != (4 or 5 or 6):
    c+=1
    a = np.random.randint(1,61,6)
    b = np.random.randint(1,61,6)

    def remover_repetidos(lista):
        l = []
        for i in lista:
            while i in l:
                i = np.random.randint(1,61)
            l.append(i)
            if i not in l:
                l.append(i)
        l.sort()
        return l

    a = remover_repetidos(a)
    b = remover_repetidos(b)

    for i in a:
        if i in b:
            n+=1
            r.append(i)
    if n < 4:
        r=[]
        n=0
    
print('Os números jogados foram:', a)
print('Os números sorteados foram:', b)
print('Números acertados:', r)
print('Quantidade de números acertados:', n)
print('Vezes jogadas:', c)
print('Total gasto: R$', c*4.5)

# %%
#simulando apenas uma jogada

import numpy as np

# ns = números sorteados
# nj = números jogados

ns = np.random.randint(1,61,6)

n1 = int(input('Digite 6 números:\n'))
n2 = int(input())
n3 = int(input())
n4 = int(input())
n5 = int(input())
n6 = int(input())
nj = [n1,n2,n3,n4,n5,n6]

while  len(nj) != len(set(nj)) or n1 > 60 or n2 > 60 or n3 > 60 or n4 > 60 or n5 > 60 or n6 > 60 or n1 < 1 or n2 < 1 or n3 < 1 or n4 < 1 or n5 < 1 or n6 < 1:
    print('Os números devem ser todos diferentes e estar no invervalo entre 1 e 60.')
    n1 = int(input('Digite 6 números:\n'))
    n2 = int(input())
    n3 = int(input())
    n4 = int(input())
    n5 = int(input())
    n6 = int(input())
    nj = [n1,n2,n3,n4,n5,n6]
    

def remover_repetidos(lista):
    l = []
    for i in lista:
        while i in l:
            i = np.random.randint(1,61)
        l.append(i)
        if i not in l:
            l.append(i)
    l.sort()
    return l

ns = remover_repetidos(ns)
nj.sort()

print('Os números sorteados foram:', ns)
print('Os números jogados foram:', nj)

# qna = quantidade de núemros acertados
# na = núemros acertados

qna = []
qna.append(set(nj).intersection(ns))

na = []
for i in qna[0]:
    na.append(i)

print('Quantidade de números acertados:', len(qna[0]))
print('Números acertados:', na)
